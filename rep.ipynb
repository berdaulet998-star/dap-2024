# %% [markdown]
# <a href="https://colab.research.google.com/github/berdaulet998-star/dap-2024/blob/main/rep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Отчёт по работе №1
# ## Цель работы
# Подготовка среды для анализа данных
#
# ## Ход работы
# - Создал аккаунт GitHub
# - Сделал форк
# - Создал аккаунт Google Colab
# - Создал отчёт о выполненной работе в Google Colab
# - Сохраните отчет в своем репозиторий github в директории ./les01
#
# -[Мой форк](https://github.com/chebotarevsa/dap-2024)
